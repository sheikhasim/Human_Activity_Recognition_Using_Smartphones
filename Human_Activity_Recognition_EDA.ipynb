# %% [markdown]
# ## Human Activity Recognition with Smartphones

# %% [markdown]
# The project is to build a model that predicts the human activities such as Walking,Walking_Upstairs,Walking_Downstairs,Sitting,Standing or Laying

# %%
# importing  necessary libraries
import numpy as np
import pandas as pd

# %% [markdown]
# ## Getting the train data

# %%
p_train = pd.read_csv('train.csv')

# %%
p_train.head(5)
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.923527         -0.934724  ...                        -0.710304
# 1         -0.957686         -0.943068  ...                        -0.861499
# 2         -0.977469         -0.938692  ...                        -0.760104
# 3         -0.989302         -0.938692  ...                        -0.482845
# 4         -0.990441         -0.942469  ...                        -0.699205
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                    -0.112754                              0.030400
# 1                     0.053477                             -0.007435
# 2                    -0.118559                              0.177899
# 3                    -0.036788                             -0.012892
# 4                     0.123320                              0.122542
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                         -0.464761                             -0.018446
# 1                         -0.732626                              0.703511
# 2                          0.100699                              0.808529
# 3                          0.640011                             -0.485366
# 4                          0.693578                             -0.615971
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  subject  \
# 0             -0.841247              0.179941             -0.058627        1
# 1             -0.844788              0.180289             -0.054317        1
# 2             -0.848933              0.180637             -0.049118        1
# 3             -0.848649              0.181935             -0.047663        1
# 4             -0.847865              0.185151             -0.043892        1
#
#    Activity
# 0  STANDING
# 1  STANDING
# 2  STANDING
# 3  STANDING
# 4  STANDING
#
# [5 rows x 563 columns]

# %%
# putting in a single dataframe
train=p_train
train.sample()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 4834           0.367729          -0.022222          -0.077729
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 4834         -0.246857         -0.090475          0.128588         -0.411232
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 4834         -0.086044           0.01345          0.428557  ...
#
#       fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 4834                        -0.569087                     -0.62034
#
#       angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 4834                             -0.157071                          0.841275
#
#       angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 4834                              0.148069             -0.865496
#
#       angle(Y,gravityMean)  angle(Z,gravityMean)  subject            Activity
# 4834              0.161252              0.089506       23  WALKING_DOWNSTAIRS
#
# [1 rows x 563 columns]

# %%
train.shape
# Out:
# (7352, 563)

# %% [markdown]
# ## Getting Test Data

# %%
p_test= pd.read_csv('test.csv')

# %%
p_test.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.674302         -0.894088  ...                        -0.705974
# 1         -0.945823         -0.894088  ...                        -0.594944
# 2         -0.963483         -0.939260  ...                        -0.640736
# 3         -0.968897         -0.938610  ...                        -0.736124
# 4         -0.977346         -0.938610  ...                        -0.846595
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                     0.006462                              0.162920
# 1                    -0.083495                              0.017500
# 2                    -0.034956                              0.202302
# 3                    -0.017067                              0.154438
# 4                    -0.002223                             -0.040046
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                         -0.825886                              0.271151
# 1                         -0.434375                              0.920593
# 2                          0.064103                              0.145068
# 3                          0.340134                              0.296407
# 4                          0.736715                             -0.118545
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  subject  \
# 0             -0.720009              0.276801             -0.057978        2
# 1             -0.698091              0.281343             -0.083898        2
# 2             -0.702771              0.280083             -0.079346        2
# 3             -0.698954              0.284114             -0.077108        2
# 4             -0.692245              0.290722             -0.073857        2
#
#    Activity
# 0  STANDING
# 1  STANDING
# 2  STANDING
# 3  STANDING
# 4  STANDING
#
# [5 rows x 563 columns]

# %% [markdown]
# # putting in a single dataframe

# %%
test= p_test
test.sample()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 1996           0.340043           0.016156          -0.095576
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 1996         -0.337403         -0.213255         -0.364295         -0.411611
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 1996         -0.201069         -0.352887           0.08118  ...
#
#       fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 1996                         -0.74733                     -0.21786
#
#       angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 1996                             -0.510124                          0.793555
#
#       angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 1996                              0.857364             -0.695778
#
#       angle(Y,gravityMean)  angle(Z,gravityMean)  subject          Activity
# 1996              0.301407             -0.036431       18  WALKING_UPSTAIRS
#
# [1 rows x 563 columns]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1. check for Duplicates

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %% [markdown]
# ## 2. checking for Nan/null values

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %% [markdown]
# ## 3. saving dataframe to csv files

# %%
train.to_csv('new_train.csv', index=False)
test.to_csv('new_test.csv', index=False)

# %% [markdown]
# ## EDA

# %% [markdown]
# ## obtaining train and test data

# %%
train= pd.read_csv('new_train.csv')
test= pd.read_csv('new_test.csv')
print(train.shape,test.shape)
# Out:
# (7352, 563) (2947, 563)

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# C:\Users\sheik\AppData\Local\Temp\ipykernel_17760\71913079.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   columns = columns.str.replace('[()]','')
# C:\Users\sheik\AppData\Local\Temp\ipykernel_17760\71913079.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   columns = columns.str.replace('[-]', '')
# C:\Users\sheik\AppData\Local\Temp\ipykernel_17760\71913079.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   columns = columns.str.replace('[,]','')
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'fBodyBodyGyroJerkMagkurtosis', 'angletBodyAccMeangravity',
#        'angletBodyAccJerkMeangravityMean', 'angletBodyGyroMeangravityMean',
#        'angletBodyGyroJerkMeangravityMean', 'angleXgravityMean',
#        'angleYgravityMean', 'angleZgravityMean', 'subject', 'Activity'],
#       dtype='object', length=563)

# %% [markdown]
# ## Checking for data imbalanced

# %%
# Importing libraries

import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='Activity', data = train)
plt.show()

# %% [markdown]
# Nearly all participants have more data for walking upstairs than downstairs. Assuming an equal number of up- and down-walks the participants need longer walking upstairs.

# %%
 #Let's check number of observations per label

plt.title('Number of Observation per Activity', fontsize=15)
sns.countplot(train.Activity)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\sheik\miniconda3\envs\mvenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Although there are fluctuations in the label counts, the labels are quite equally distributed.
#
# Assuming the participants had to walk the same number of stairs upwards as well as downwards and knowing the smartphones had a constant sampling rate, there should be the same amount of datapoints for walking upstairs and downstairs.
#
# Disregarding the possibility of flawed data, the participants seem to walk roughly 10% faster downwards.

# %% [markdown]
# ## Static and Dynamic Activities
#
# In static activities (sit, stand, lie down) motion information will not be very useful.
# In the dynamic activities (Walking, WalkingUpstairs,WalkingDownstairs) motion info will be significant.

# %% [markdown]
# ## Stationary and Moving activities are completely different

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='Activity', height=5,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.960,12), xytext=(-0.5, 15), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()
# Out:
# C:\Users\sheik\miniconda3\envs\mvenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\sheik\miniconda3\envs\mvenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\sheik\miniconda3\envs\mvenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\sheik\miniconda3\envs\mvenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\sheik\miniconda3\envs\mvenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\sheik\miniconda3\envs\mvenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['subject']==1]
df2 = train[train['subject']==2]
df3 = train[train['subject']==3]
df4 = train[train['subject']==4]
df5 = train[train['subject']==5]
df6 = train[train['subject']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.08, -0.2, 0.1, 20])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()
# Out:
# C:\Users\sheik\miniconda3\envs\mvenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\sheik\miniconda3\envs\mvenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\sheik\miniconda3\envs\mvenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\sheik\miniconda3\envs\mvenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\sheik\miniconda3\envs\mvenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\sheik\miniconda3\envs\mvenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Magnitude of an acceleration can saperate it well

# %%
# Let's plot a boxplot to check the same

plt.figure(figsize=(8,8))
sns.boxplot(x='Activity', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.xticks(rotation=90)
plt.axhline(y=-0.7, xmin=0.0, xmax=1.0, dashes=(5,5), c='r')
plt.axhline(y=0.02, xmin=0.0, xmax=1.0, dashes=(5,5), c='g')
plt.show()

# %% [markdown]
# If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
#
# If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
#
# If tAccMean > 0.0 then the Activity is WalkingDownstairs.
#
# We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
#  ## Position of GravityAccelerationComponants also matters

# %%
sns.boxplot(x='Activity', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# If angleX,gravityMean > 0 then Activity is Laying

# %% [markdown]
# ## Apply t-sne on the data

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, height=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject','Activity'], axis=1)
y_pre_tsne = train['Activity']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.006s...
# C:\Users\sheik\miniconda3\envs\mvenv\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\sheik\miniconda3\envs\mvenv\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computed neighbors for 7352 samples in 1.775s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.597464
# [t-SNE] Computed conditional probabilities in 0.025s
# [t-SNE] Iteration 50: error = 124.7331848, gradient norm = 0.0274167 (50 iterations in 0.952s)
# [t-SNE] Iteration 100: error = 107.1949005, gradient norm = 0.0295973 (50 iterations in 0.739s)
# [t-SNE] Iteration 150: error = 100.9357605, gradient norm = 0.0206780 (50 iterations in 0.680s)
# [t-SNE] Iteration 200: error = 97.4941330, gradient norm = 0.0176602 (50 iterations in 0.663s)
# [t-SNE] Iteration 250: error = 95.1504440, gradient norm = 0.0126492 (50 iterations in 0.672s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.150444
# [t-SNE] Iteration 300: error = 4.1147985, gradient norm = 0.0015603 (50 iterations in 0.652s)
# [t-SNE] Iteration 350: error = 3.2049141, gradient norm = 0.0009862 (50 iterations in 0.715s)
# [t-SNE] Iteration 400: error = 2.7755325, gradient norm = 0.0007199 (50 iterations in 0.760s)
# [t-SNE] Iteration 450: error = 2.5112829, gradient norm = 0.0005662 (50 iterations in 0.735s)
# [t-SNE] Iteration 500: error = 2.3279734, gradient norm = 0.0004727 (50 iterations in 0.739s)
# [t-SNE] Iteration 550: error = 2.1905441, gradient norm = 0.0004111 (50 iterations in 0.775s)
# [t-SNE] Iteration 600: error = 2.0813212, gradient norm = 0.0003690 (50 iterations in 0.759s)
# [t-SNE] Iteration 650: error = 1.9918342, gradient norm = 0.0003330 (50 iterations in 0.774s)
# [t-SNE] Iteration 700: error = 1.9161322, gradient norm = 0.0003025 (50 iterations in 0.740s)
# [t-SNE] Iteration 750: error = 1.8514850, gradient norm = 0.0002773 (50 iterations in 0.745s)
# [t-SNE] Iteration 800: error = 1.7949505, gradient norm = 0.0002569 (50 iterations in 0.705s)
# [t-SNE] Iteration 850: error = 1.7447579, gradient norm = 0.0002404 (50 iterations in 0.697s)
# [t-SNE] Iteration 900: error = 1.6999274, gradient norm = 0.0002210 (50 iterations in 0.706s)
# [t-SNE] Iteration 950: error = 1.6598272, gradient norm = 0.0002129 (50 iterations in 0.739s)
# [t-SNE] Iteration 1000: error = 1.6235564, gradient norm = 0.0001993 (50 iterations in 0.722s)
# [t-SNE] KL divergence after 1000 iterations: 1.623556
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.010s...
# C:\Users\sheik\miniconda3\envs\mvenv\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\sheik\miniconda3\envs\mvenv\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computed neighbors for 7352 samples in 1.682s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961446
# [t-SNE] Computed conditional probabilities in 0.029s
# [t-SNE] Iteration 50: error = 114.1043091, gradient norm = 0.0234482 (50 iterations in 1.148s)
# [t-SNE] Iteration 100: error = 97.1193466, gradient norm = 0.0159366 (50 iterations in 0.778s)
# [t-SNE] Iteration 150: error = 93.0640640, gradient norm = 0.0082583 (50 iterations in 0.760s)
# [t-SNE] Iteration 200: error = 91.1385956, gradient norm = 0.0065353 (50 iterations in 0.796s)
# [t-SNE] Iteration 250: error = 89.9815140, gradient norm = 0.0069564 (50 iterations in 0.722s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 89.981514
# [t-SNE] Iteration 300: error = 3.5718451, gradient norm = 0.0014632 (50 iterations in 0.756s)
# [t-SNE] Iteration 350: error = 2.8132753, gradient norm = 0.0007481 (50 iterations in 0.755s)
# [t-SNE] Iteration 400: error = 2.4321985, gradient norm = 0.0005291 (50 iterations in 0.711s)
# [t-SNE] Iteration 450: error = 2.2142830, gradient norm = 0.0004092 (50 iterations in 0.741s)
# [t-SNE] Iteration 500: error = 2.0697894, gradient norm = 0.0003295 (50 iterations in 0.755s)
# [t-SNE] Iteration 550: error = 1.9644713, gradient norm = 0.0002821 (50 iterations in 0.735s)
# [t-SNE] Iteration 600: error = 1.8834060, gradient norm = 0.0002459 (50 iterations in 0.723s)
# [t-SNE] Iteration 650: error = 1.8181794, gradient norm = 0.0002182 (50 iterations in 0.756s)
# [t-SNE] Iteration 700: error = 1.7642932, gradient norm = 0.0001965 (50 iterations in 0.798s)
# [t-SNE] Iteration 750: error = 1.7189206, gradient norm = 0.0001788 (50 iterations in 0.749s)
# [t-SNE] Iteration 800: error = 1.6798961, gradient norm = 0.0001658 (50 iterations in 0.783s)
# [t-SNE] Iteration 850: error = 1.6460296, gradient norm = 0.0001529 (50 iterations in 0.752s)
# [t-SNE] Iteration 900: error = 1.6161872, gradient norm = 0.0001425 (50 iterations in 0.748s)
# [t-SNE] Iteration 950: error = 1.5897486, gradient norm = 0.0001339 (50 iterations in 0.751s)
# [t-SNE] Iteration 1000: error = 1.5662796, gradient norm = 0.0001246 (50 iterations in 0.734s)
# [t-SNE] KL divergence after 1000 iterations: 1.566280
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.006s...
# C:\Users\sheik\miniconda3\envs\mvenv\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\sheik\miniconda3\envs\mvenv\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computed neighbors for 7352 samples in 1.656s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133827
# [t-SNE] Computed conditional probabilities in 0.055s
# [t-SNE] Iteration 50: error = 105.3227997, gradient norm = 0.0268239 (50 iterations in 1.050s)
# [t-SNE] Iteration 100: error = 90.2934341, gradient norm = 0.0112870 (50 iterations in 0.847s)
# [t-SNE] Iteration 150: error = 87.2957840, gradient norm = 0.0058925 (50 iterations in 0.848s)
# [t-SNE] Iteration 200: error = 86.0934601, gradient norm = 0.0036289 (50 iterations in 0.838s)
# [t-SNE] Iteration 250: error = 85.4139252, gradient norm = 0.0038496 (50 iterations in 0.835s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.413925
# [t-SNE] Iteration 300: error = 3.1367962, gradient norm = 0.0013900 (50 iterations in 0.788s)
# [t-SNE] Iteration 350: error = 2.4940438, gradient norm = 0.0006479 (50 iterations in 0.760s)
# [t-SNE] Iteration 400: error = 2.1749127, gradient norm = 0.0004216 (50 iterations in 0.764s)
# [t-SNE] Iteration 450: error = 1.9907910, gradient norm = 0.0003129 (50 iterations in 0.763s)
# [t-SNE] Iteration 500: error = 1.8729625, gradient norm = 0.0002503 (50 iterations in 0.767s)
# [t-SNE] Iteration 550: error = 1.7897846, gradient norm = 0.0002094 (50 iterations in 0.840s)
# [t-SNE] Iteration 600: error = 1.7273618, gradient norm = 0.0001826 (50 iterations in 0.805s)
# [t-SNE] Iteration 650: error = 1.6784821, gradient norm = 0.0001588 (50 iterations in 0.810s)
# [t-SNE] Iteration 700: error = 1.6387697, gradient norm = 0.0001426 (50 iterations in 0.825s)
# [t-SNE] Iteration 750: error = 1.6060119, gradient norm = 0.0001289 (50 iterations in 0.808s)
# [t-SNE] Iteration 800: error = 1.5782501, gradient norm = 0.0001220 (50 iterations in 0.785s)
# [t-SNE] Iteration 850: error = 1.5547473, gradient norm = 0.0001112 (50 iterations in 0.787s)
# [t-SNE] Iteration 900: error = 1.5344442, gradient norm = 0.0001068 (50 iterations in 0.785s)
# [t-SNE] Iteration 950: error = 1.5170541, gradient norm = 0.0000998 (50 iterations in 0.779s)
# [t-SNE] Iteration 1000: error = 1.5019958, gradient norm = 0.0000939 (50 iterations in 0.787s)
# [t-SNE] KL divergence after 1000 iterations: 1.501996
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.006s...
# C:\Users\sheik\miniconda3\envs\mvenv\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\sheik\miniconda3\envs\mvenv\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computed neighbors for 7352 samples in 1.543s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274336
# [t-SNE] Computed conditional probabilities in 0.102s
# [t-SNE] Iteration 50: error = 97.7903366, gradient norm = 0.0168036 (50 iterations in 1.081s)
# [t-SNE] Iteration 100: error = 84.3342667, gradient norm = 0.0071535 (50 iterations in 1.010s)
# [t-SNE] Iteration 150: error = 82.0054092, gradient norm = 0.0036190 (50 iterations in 0.929s)
# [t-SNE] Iteration 200: error = 81.2319031, gradient norm = 0.0027021 (50 iterations in 0.925s)
# [t-SNE] Iteration 250: error = 80.8355865, gradient norm = 0.0019992 (50 iterations in 0.931s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.835587
# [t-SNE] Iteration 300: error = 2.6977661, gradient norm = 0.0013023 (50 iterations in 0.890s)
# [t-SNE] Iteration 350: error = 2.1653585, gradient norm = 0.0005724 (50 iterations in 0.853s)
# [t-SNE] Iteration 400: error = 1.9169171, gradient norm = 0.0003468 (50 iterations in 0.852s)
# [t-SNE] Iteration 450: error = 1.7710956, gradient norm = 0.0002484 (50 iterations in 0.864s)
# [t-SNE] Iteration 500: error = 1.6773874, gradient norm = 0.0001930 (50 iterations in 0.875s)
# [t-SNE] Iteration 550: error = 1.6133898, gradient norm = 0.0001576 (50 iterations in 0.873s)
# [t-SNE] Iteration 600: error = 1.5668756, gradient norm = 0.0001351 (50 iterations in 0.885s)
# [t-SNE] Iteration 650: error = 1.5315363, gradient norm = 0.0001184 (50 iterations in 0.887s)
# [t-SNE] Iteration 700: error = 1.5040988, gradient norm = 0.0001042 (50 iterations in 0.895s)
# [t-SNE] Iteration 750: error = 1.4818882, gradient norm = 0.0000960 (50 iterations in 0.904s)
# [t-SNE] Iteration 800: error = 1.4637918, gradient norm = 0.0000894 (50 iterations in 0.881s)
# [t-SNE] Iteration 850: error = 1.4494470, gradient norm = 0.0000826 (50 iterations in 0.891s)
# [t-SNE] Iteration 900: error = 1.4376853, gradient norm = 0.0000786 (50 iterations in 0.877s)
# [t-SNE] Iteration 950: error = 1.4281796, gradient norm = 0.0000758 (50 iterations in 0.902s)
# [t-SNE] Iteration 1000: error = 1.4202417, gradient norm = 0.0000716 (50 iterations in 0.914s)
# [t-SNE] KL divergence after 1000 iterations: 1.420242
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.006s...
# C:\Users\sheik\miniconda3\envs\mvenv\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\sheik\miniconda3\envs\mvenv\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computed neighbors for 7352 samples in 1.724s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.241s
# [t-SNE] Iteration 50: error = 86.9094849, gradient norm = 0.0140298 (50 iterations in 1.470s)
# [t-SNE] Iteration 100: error = 75.7532120, gradient norm = 0.0045813 (50 iterations in 1.391s)
# [t-SNE] Iteration 150: error = 74.7576141, gradient norm = 0.0024241 (50 iterations in 1.347s)
# [t-SNE] Iteration 200: error = 74.3276978, gradient norm = 0.0016890 (50 iterations in 1.314s)
# [t-SNE] Iteration 250: error = 74.1430740, gradient norm = 0.0013460 (50 iterations in 1.336s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.143074
# [t-SNE] Iteration 300: error = 2.1652291, gradient norm = 0.0011919 (50 iterations in 1.274s)
# [t-SNE] Iteration 350: error = 1.7643348, gradient norm = 0.0004937 (50 iterations in 1.282s)
# [t-SNE] Iteration 400: error = 1.5943489, gradient norm = 0.0002827 (50 iterations in 1.269s)
# [t-SNE] Iteration 450: error = 1.5002068, gradient norm = 0.0001895 (50 iterations in 1.287s)
# [t-SNE] Iteration 500: error = 1.4400375, gradient norm = 0.0001397 (50 iterations in 1.268s)
# [t-SNE] Iteration 550: error = 1.3985986, gradient norm = 0.0001115 (50 iterations in 1.295s)
# [t-SNE] Iteration 600: error = 1.3689851, gradient norm = 0.0000929 (50 iterations in 1.291s)
# [t-SNE] Iteration 650: error = 1.3474442, gradient norm = 0.0000828 (50 iterations in 1.297s)
# [t-SNE] Iteration 700: error = 1.3313476, gradient norm = 0.0000754 (50 iterations in 1.248s)
# [t-SNE] Iteration 750: error = 1.3195572, gradient norm = 0.0000675 (50 iterations in 1.294s)
# [t-SNE] Iteration 800: error = 1.3106242, gradient norm = 0.0000634 (50 iterations in 1.295s)
# [t-SNE] Iteration 850: error = 1.3034194, gradient norm = 0.0000608 (50 iterations in 1.285s)
# [t-SNE] Iteration 900: error = 1.2975433, gradient norm = 0.0000583 (50 iterations in 1.270s)
# [t-SNE] Iteration 950: error = 1.2927196, gradient norm = 0.0000562 (50 iterations in 1.253s)
# [t-SNE] Iteration 1000: error = 1.2888057, gradient norm = 0.0000565 (50 iterations in 1.248s)
# [t-SNE] KL divergence after 1000 iterations: 1.288806
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done

# %% [markdown]
# We can clearly see the TSNE cluster, All the Activity are clean seperate except "Standing" and "Sitting".
